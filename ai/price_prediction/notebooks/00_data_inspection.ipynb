# %% [markdown]
# # Mandi Price Data Inspection
# This notebook inspects raw AGMARKNET daily price data for missing dates, column schemas, and price anomalies.

# %%
import pandas as pd

# Load raw sample data (adjust path when running locally)
# df = pd.read_csv('../../../data/raw/mandi/sample_mandi.csv')

print('Dataset Inspection Checklist:')
print('1. Total row count')
print('2. Date range coverage')
print('3. Missing price values count')
print('4. Duplicate market entries')
