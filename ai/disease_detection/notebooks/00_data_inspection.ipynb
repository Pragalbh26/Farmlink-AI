# %% [markdown]
# # Plant Village Image Dataset Inspection
# This notebook iterates through disease image directories to check class counts and detect corrupt image files.

# %%
import os

# Path to raw images
data_dir = '../../../data/raw/disease'

print('Disease Image Inspection Checklist:')
print('1. Class directory names')
print('2. Total image count per class')
print('3. Corrupted or unreadable image verification')
